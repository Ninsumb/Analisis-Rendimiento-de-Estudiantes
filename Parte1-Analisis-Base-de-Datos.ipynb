# %% [markdown]
# ## **Parte 1: Análisis de la Base de Datos**
#
# ### Seleccion
#
# Primero, presento el enlace a Kaggle de mi elección para la base de datos: [Factores en el Rendimiento de los Estudiantes](https://www.kaggle.com/datasets/lainguyn123/student-performance-factors?resource=download). Adjunto en el proyecto está el csv que usaré para el trabajo, los datos están en inglés y son generados (no son datos de alumnos reales) con el criterio de simular escenarios realistas y, como explica el autor, su propósito es educacional.
#
# ### Análisis de los datos
#
# #### **Punto 1:** Describe cada columna del conjunto de datos:
#
# * **Horas de Estudio**: Numero de horas que el alumno invirtió en estudiar semanalmente. El dato es un numero entero, y se trata de una variable discreta.
#
# * **Asistencia**: Porcentaje de asistencia del alumno. Es un numero entero en un rango de 60 a 100. Es una variable continua, pero no hay valores intermedios (decimales).
#
# * **Participación de los Padres/Familia**: Nivel de participación de los padres en el desarrollo educativo del estudiante. Es una variable ordinal, que es como una variable categórica pero con un orden, por lo que existe una clasificación para medir (alta, media, baja).
#
# * **Acceso a Recursos**: Disponibilidad de recursos educacionales. También es una variable ordinal (alta, media, baja).
#
# * **Actividades Extracurriculares**: Si el estudiante realiza o no actividades aparte. Variable binaria (si, no).
#
# * **Horas de Sueño**: Promedio de horas de sueño por noche. Varible discreta.
#
# * **Puntajes previos**: Puntuación de examenes anteriores, se interpreta más bien como el promedio del estudiante. Es una variable continua que va de 50 a 100.
#
# * **Nivel de Motivación**: El nivel de motivación del estudiante. Variable ordinal (alta, media, baja).
#
# * **Acceso a Internet**: Es la disponibilidad del acceso a internet del alumno. Variabla binaria (si, no).
#
# * **Clases Particulares**: Numero de clases particulares al que se atendió por mes. Variable discreta.
#
# * **Ingresos Familiares**: El ingreso ecónomico de la familia del estudiante (salarios, sueldos, etc). Variable ordinal (alta, media, baja).
#
# * **Calidad del Profesor**: Calidad de la enseñanza y los recursos didácticos del profesor. Otra variable ordinal (alta, media, baja).
#
# * **Tipo de Escuela**: Tipo de escuela a la que atiende el alumno (pública, privada), será una variable categórica (sin orden ni magnitud).
#
# * **Influencia de los Compañeros**: Influencia del resto de esutdiantes sobre el rendimiento academico. Variable ordinal (positiva, neutral, negativa).
#
# * **Actividad Física**: Promedio entero de las horas en las que el estudiante hace algún tipo de actividad física en la semana. Variable discreta.
#
# * **Discapacidades en el Aprendizaje**: Presencia de discapacidades que puedan tener un impacto en el aprendizaje. Variable binaria (si, no).
#
# * **Nivel Educacional de los Padres**: El nivel educativo más alto alcanzado por los padres del estudiante. Variable categórica (secundaria, universidad, posgraduación).
#
# * **Distancia desde el Hogar**: Distancia desde el hogar a la escuela. Variable ordinal (cerca, moderada, lejos).
#
# * **Género**: Variable categórica (Masculino, femenino).
#
# * **Nota del Examen**: Nota final del examen. Variable continua. //Duda respecto a la base de datos en sí --> El valor max es 101?

# %%
import pandas as pd

data = pd.read_csv('StudentPerformanceFactors (1).csv', delimiter=',', index_col=0)
df = pd.DataFrame(data)

df
# Out:
#                Attendance Parental_Involvement Access_to_Resources  \
# Hours_Studied
# 23                     84                  Low                High
# 19                     64                  Low              Medium
# 24                     98               Medium              Medium
# 29                     89                  Low              Medium
# 19                     92               Medium              Medium
# ...                   ...                  ...                 ...
# 25                     69                 High              Medium
# 23                     76                 High              Medium
# 20                     90               Medium                 Low
# 10                     86                 High                High
# 15                     67               Medium                 Low
#
#               Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# Hours_Studied
# 23                                    No            7               73
# 19                                    No            8               59
# 24                                   Yes            7               91
# 29                                   Yes            8               98
# 19                                   Yes            6               65
# ...                                  ...          ...              ...
# 25                                    No            7               76
# 23                                    No            8               81
# 20                                   Yes            6               65
# 10                                   Yes            6               91
# 15                                   Yes            9               94
#
#               Motivation_Level Internet_Access  Tutoring_Sessions  \
# Hours_Studied
# 23                         Low             Yes                  0
# 19                         Low             Yes                  2
# 24                      Medium             Yes                  2
# 29                      Medium             Yes                  1
# 19                      Medium             Yes                  3
# ...                        ...             ...                ...
# 25                      Medium             Yes                  1
# 23                      Medium             Yes                  3
# 20                         Low             Yes                  3
# 10                        High             Yes                  2
# 15                      Medium             Yes                  0
#
#               Family_Income Teacher_Quality School_Type Peer_Influence  \
# Hours_Studied
# 23                      Low          Medium      Public       Positive
# 19                   Medium          Medium      Public       Negative
# 24                   Medium          Medium      Public        Neutral
# 29                   Medium          Medium      Public       Negative
# 19                   Medium            High      Public        Neutral
# ...                     ...             ...         ...            ...
# 25                     High          Medium      Public       Positive
# 23                      Low            High      Public       Positive
# 20                      Low          Medium      Public       Negative
# 10                      Low          Medium     Private       Positive
# 15                   Medium          Medium      Public       Positive
#
#                Physical_Activity Learning_Disabilities  \
# Hours_Studied
# 23                             3                    No
# 19                             4                    No
# 24                             4                    No
# 29                             4                    No
# 19                             4                    No
# ...                          ...                   ...
# 25                             2                    No
# 23                             2                    No
# 20                             2                    No
# 10                             3                    No
# 15                             4                    No
#
#               Parental_Education_Level Distance_from_Home  Gender  Exam_Score
# Hours_Studied
# 23                         High School               Near    Male          67
# 19                             College           Moderate  Female          61
# 24                        Postgraduate               Near    Male          74
# 29                         High School           Moderate    Male          71
# 19                             College               Near  Female          70
# ...                                ...                ...     ...         ...
# 25                         High School               Near  Female          68
# 23                         High School               Near  Female          69
# 20                        Postgraduate               Near  Female          68
# 10                         High School                Far  Female          68
# 15                        Postgraduate               Near    Male          64
#
# [6607 rows x 19 columns]

# %% [markdown]
# Acá abajo veremos un ejemplo de como la función dtypes nos devuelve una idea básica de los tipos de datos  de cada columna:

# %%
import pandas as pd


df = pd.read_csv("StudentPerformanceFactors (1).csv")


print(df.dtypes)
# Out:
# Hours_Studied                  int64
# Attendance                     int64
# Parental_Involvement          object
# Access_to_Resources           object
# Extracurricular_Activities    object
# Sleep_Hours                    int64
# Previous_Scores                int64
# Motivation_Level              object
# Internet_Access               object
# Tutoring_Sessions              int64
# Family_Income                 object
# Teacher_Quality               object
# School_Type                   object
# Peer_Influence                object
# Physical_Activity              int64
# Learning_Disabilities         object
# Parental_Education_Level      object
# Distance_from_Home            object
# Gender                        object
# Exam_Score                     int64
# dtype: object

# %% [markdown]
# Como podemos ver, el tipo "object" corresponde a variables categóricas o ordinales, y el tipo "int64" corresponde a variables discretas o continuas (notar que en la base de datos no se trabaja en ningun momento con valores decimales).

# %% [markdown]
# #### **Punto 2:** Análisis de Correlaciones:
#
# Antes de hacer el punto 2, tendré que saltar a completar parte de lo que pide el **Punto 5**(Transformaciones Preliminares). Esto se debe a que para ver y analizar las correlaciones tendré que estar trabajando con datos númericos. Lo primero que haré es simplificar los datos "complejos" (todas las variables que no sean númericas) en diccionarios. Luego, haré lo mismo para las variables continuas (que son rangos, porcentajes). En el punto 5 retomaré para normalizar las variables de las notas también (previas y la nota final, que es nuestra 'Columna Objetivo'), así tenerlas de un rango de 0 a 1 y trabajar con más comodidad en valores binarios (que serán 'Aprobado' y 'Desaprovado').

# %%
par_involvment = {'Low': 0, 'Medium': 1, 'High': 2}

acc_resources = {'Low': 0, 'Medium': 1, 'High': 2}

extrc_activities = {'No': 0, 'Yes': 1}

motv_level = {'Low': 0, 'Medium': 1, 'High': 2}

internet_acc = {'No': 0, 'Yes': 1}

fam_income = {'Low': 0, 'Medium': 1, 'High': 2}

teacher_qlty = {'Low': 0, 'Medium': 1, 'High': 2} #

sch_type = {'Public': 0, 'Private': 1}

peer_infl = {'Negative': 0, 'Neutral': 1, 'Positive': 2}

learning_dis = {'No': 0, 'Yes': 1}

parental_edu = {'High School': 0, 'College': 1, 'Postgraduate': 2} #

dist = {'Near': 0, 'Moderate': 1, 'Far': 2} #Por algun motivo TODAS las columnas con # devuelven numero flotante

gender = {'Male': 0, 'Female': 1}

#########################################################################################################################################

#Quiero mantener todo mas o menos en un rango de 8. Para los puntajaes voy a usar rango de 10. 

attnd = {
    (59, 65):   0,
    (65, 70):   1,
    (70, 75):   2,
    (75, 80):   3,
    (80, 85):   4,
    (85, 90):   5,
    (90, 95):   6,
    (95, 100):  7
}

prev_score = {
    (50, 55):   0,
    (56, 60):   1,
    (61, 65):   2,
    (66, 70):   3,
    (71, 75):   4, #Recordar que de 4 para arriba será >=70. Osea que tomaré luego de 4 para arriba como "Aprobado". 
    (76, 80):   5,
    (81, 85):   6,
    (86, 90):   7,
    (91, 95):   8,
    (95, 100):  9
}
#Recordar que de 4 para arriba será >=70. Osea que tomaré luego de 4 para arriba como "Aprobado". 

fin_score = {
    (50, 55):   0,
    (56, 60):   1,
    (61, 65):   2,
    (66, 70):   3,
    (71, 75):   4, #De acá en adelante, aprobado
    (76, 80):   5,
    (81, 85):   6,
    (86, 90):   7,
    (91, 95):   8,
    (96, 102):  9 #El valor maximo es 101 (por lo que sea) 
}

# %% [markdown]
# Teniendo ya listos los diccionarios para la nueva base de datos simplificada, prosigo con el reemplazo.

# %%
remp = {
    'Parental_Involvement':par_involvment,
    'Access_to_Resources':acc_resources,
    'Extracurricular_Activities':extrc_activities,
    'Motivation_Level':motv_level,
    'Internet_Access':internet_acc,
    'Family_Income':fam_income,
    'Teacher_Quality':teacher_qlty,
    'School_Type':sch_type,
    'Peer_Influence':peer_infl,
    'Learning_Disabilities':learning_dis,
    'Parental_Education_Level':parental_edu,
    'Distance_from_Home':dist,
    'Gender': gender
}

for columna, valor_simple in remp.items():
    if columna in df.columns:
        df[columna] = df[columna].replace(valor_simple)


#Ahora remplazo las variables con rango

def remplazar(valores, rango):
    for diccionario, grupo in rango.items():
        if (diccionario[0] <= valores)and(valores <= diccionario[1]):
            return grupo
    return -1

df['Attendance'] = df['Attendance'].apply(lambda x: remplazar(x, attnd)) 
df['Previous_Scores'] = df['Previous_Scores'].apply(lambda x: remplazar(x, prev_score)) 
df['Exam_Score'] = df['Exam_Score'].apply(lambda x: remplazar(x, fin_score))


df
# Out:
# C:\Users\PC-Home\AppData\Local\Temp\ipykernel_15448\3771008318.py:19: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[columna] = df[columna].replace(valor_simple)
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23           4                     0                    2
# 1                19           0                     0                    1
# 2                24           7                     1                    1
# 3                29           5                     0                    1
# 4                19           6                     1                    1
# ...             ...         ...                   ...                  ...
# 6602             25           1                     2                    1
# 6603             23           3                     2                    1
# 6604             20           5                     1                    0
# 6605             10           5                     2                    2
# 6606             15           1                     1                    0
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 0                              0            7                4
# 1                              0            8                1
# 2                              1            7                8
# 3                              1            8                9
# 4                              1            6                2
# ...                          ...          ...              ...
# 6602                           0            7                5
# 6603                           0            8                6
# 6604                           1            6                2
# 6605                           1            6                8
# 6606                           1            9                8
#
#       Motivation_Level  Internet_Access  Tutoring_Sessions  Family_Income  \
# 0                    0                1                  0              0
# 1                    0                1                  2              1
# 2                    1                1                  2              1
# 3                    1                1                  1              1
# 4                    1                1                  3              1
# ...                ...              ...                ...            ...
# 6602                 1                1                  1              2
# 6603                 1                1                  3              0
# 6604                 0                1                  3              0
# 6605                 2                1                  2              0
# 6606                 1                1                  0              1
#
#       Teacher_Quality  School_Type  Peer_Influence  Physical_Activity  \
# 0                 1.0            0               2                  3
# 1                 1.0            0               0                  4
# 2                 1.0            0               1                  4
# 3                 1.0            0               0                  4
# 4                 2.0            0               1                  4
# ...               ...          ...             ...                ...
# 6602              1.0            0               2                  2
# 6603              2.0            0               2                  2
# 6604              1.0            0               0                  2
# 6605              1.0            1               2                  3
# 6606              1.0            0               2                  4
#
#       Learning_Disabilities  Parental_Education_Level  Distance_from_Home  \
# 0                         0                       0.0                 0.0
# 1                         0                       1.0                 1.0
# 2                         0                       2.0                 0.0
# 3                         0                       0.0                 1.0
# 4                         0                       1.0                 0.0
# ...                     ...                       ...                 ...
# 6602                      0                       0.0                 0.0
# 6603                      0                       0.0                 0.0
# 6604                      0                       2.0                 0.0
# 6605                      0                       0.0                 2.0
# 6606                      0                       2.0                 0.0
#
#       Gender  Exam_Score
# 0          0           3
# 1          1           2
# 2          0           4
# 3          0           4
# 4          1           3
# ...      ...         ...
# 6602       1           3
# 6603       1           3
# 6604       1           3
# 6605       1           3
# 6606       0           2
#
# [6607 rows x 20 columns]

# %% [markdown]
# Ya con los datos transformados en valores simples, podemos ver la correlación entre las variables:

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

matriz_corr = df.corr()

plt.figure(figsize=(15,15))
sns.heatmap(matriz_corr,annot=True,fmt=".2f",cmap='plasma')
plt.title("Mapa de Correlación")

plt.show()

# %% [markdown]
# Use una paleta de colores que, a mi criterio personal, me ayuda a visualizar más facilmente las relaciones entre las variables.
#
# ##### **Observaciones**:
#
# Podemos ver que la variable que más depende de las demás es nuestra Columna Objetivo, "Exam_Score": La nota que obtiene el alumno finalmente tras las consideraciones del resto de columnas de características. Las variables más inversamente propocionales que tenemos respecto a la nota del examen son "Learning_Disabilities" y "Distance_from_Home", pero son demasiado bajas como para considerarlas factores importantes. Luego, la mayoría parecen tender más a la no-correlación excepto las dos que más nos importan: "Hours_Studied" y "Attendance". Estas dos son las que más van a influir en el éxito del estudiante.

# %% [markdown]
# #### **Punto 3:** Análisis de Factibilidad.
#
# Esta base de datos con variables sintéticas es adecuada para hacer una predicción simple de clasificación. El volumen de datos con el que contamos es de 6607 filas, una cantidad
# adecuada para analizar el rendimiento de los alumnos. Tiene un montón de características que no influyen tanto como uno podría creer (sin querer caer en una idea sesgada del modelo, este tipo de variables que "no afectan tanto" podrían tener más impacto en una población más reducida, como una muestra). En la Columna Objetivo tendremos la nota final del estudiante, que como vimos en el punto anterior, las variables por las que más se ve afectada son la asistencia a clase y las horas de estudio. Tiene sentido, al final en la vida real ambos factores son los más definitivos para predecir el éxito que tendrá un alumno en el examen para el que está estudiando (aunque no hay que olvidar que acá no estamos buscando sentido según lo que uno podría observar o esperar en la vida real, excepto quizás a la hora de sacar conclusiones del resultado final del trabajo, sino que tan solo estamos analizando datos). Lo que se buscará predecir es si el estudiante aprobará o no el examen, basando el modelo en las variables de Hours_Studied y Attendance. Hay que recordar que estamos usando datos artificiales. Si tomaramos una muestra (menor cantidad) de una escuela cercana a la UNSAM, por ejemplo, los resultados de correlación de otras variables podrían sorprendernos. En cambio, si tomaramos muestras de varias escuelas al azar, estén cercanas o no a la UNSAM (podrían ser escuelas de todo el mundo), el resultado se parecería más al que obtenemos con esta base de datos... En general. La ubicación importa, el país importa, también su cultura y sociedad. La ciudad, la época del año, la generación a la que pertenecen los estudiantes, las condiciones de la escuela y tantas otras consideraciones más. Por eso, nos manejaremos de esta manera para la base de datos seleccionada, como si fuesen estadísticas generales.

# %% [markdown]
# #### **Punto 4:** Datos atípicos y Limpieza de Datos:

# %%
df.describe()
# Out:
#        Hours_Studied   Attendance  Parental_Involvement  Access_to_Resources  \
# count    6607.000000  6607.000000           6607.000000          6607.000000
# mean       19.975329     3.410625              1.086423             1.100197
# std         5.990594     2.288891              0.695521             0.698347
# min         1.000000     0.000000              0.000000             0.000000
# 25%        16.000000     1.000000              1.000000             1.000000
# 50%        20.000000     3.000000              1.000000             1.000000
# 75%        24.000000     5.000000              2.000000             2.000000
# max        44.000000     7.000000              2.000000             2.000000
#
#        Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# count                 6607.000000   6607.00000      6607.000000
# mean                     0.596035      7.02906         4.424852
# std                      0.490728      1.46812         2.864443
# min                      0.000000      4.00000         0.000000
# 25%                      0.000000      6.00000         2.000000
# 50%                      1.000000      7.00000         4.000000
# 75%                      1.000000      8.00000         7.000000
# max                      1.000000     10.00000         9.000000
#
#        Motivation_Level  Internet_Access  Tutoring_Sessions  Family_Income  \
# count       6607.000000      6607.000000        6607.000000    6607.000000
# mean           0.906463         0.924474           1.493719       0.787649
# std            0.695798         0.264258           1.230570       0.742617
# min            0.000000         0.000000           0.000000       0.000000
# 25%            0.000000         1.000000           1.000000       0.000000
# 50%            1.000000         1.000000           1.000000       1.000000
# 75%            1.000000         1.000000           2.000000       1.000000
# max            2.000000         1.000000           8.000000       2.000000
#
#        Teacher_Quality  School_Type  Peer_Influence  Physical_Activity  \
# count      6529.000000  6607.000000     6607.000000        6607.000000
# mean          1.197580     0.304071        1.190858           2.967610
# std           0.599878     0.460048        0.755876           1.031231
# min           0.000000     0.000000        0.000000           0.000000
# 25%           1.000000     0.000000        1.000000           2.000000
# 50%           1.000000     0.000000        1.000000           3.000000
# 75%           2.000000     1.000000        2.000000           4.000000
# max           2.000000     1.000000        2.000000           6.000000
#
#        Learning_Disabilities  Parental_Education_Level  Distance_from_Home  \
# count            6607.000000               6517.000000         6540.000000
# mean                0.105191                  0.705693            0.506728
# std                 0.306823                  0.779920            0.671749
# min                 0.000000                  0.000000            0.000000
# 25%                 0.000000                  0.000000            0.000000
# 50%                 0.000000                  1.000000            0.000000
# 75%                 0.000000                  1.000000            1.000000
# max                 1.000000                  2.000000            2.000000
#
#             Gender   Exam_Score
# count  6607.000000  6607.000000
# mean      0.422733     2.847435
# std       0.494031     0.825367
# min       0.000000     0.000000
# 25%       0.000000     2.000000
# 50%       0.000000     3.000000
# 75%       1.000000     3.000000
# max       1.000000     9.000000

# %% [markdown]
# A simple vista no vemos datos anormales teniendo en cuenta nuestras variables iniciales. Naturalmente, el promedio y la desviacion estándar cambiarán cuando llegemos al punto 5 (donde vamos a normalizar algunas columnas).

# %% [markdown]
# Primero, voy a reducir el rango de horas estudiadas para poder interpretar mejor.

# %%
hs_studied = {
    (0,7):      0,
    (8, 14):    1,
    (15, 21):   2,
    (22, 28):   3,
    (29, 35):   4,
    (36, 42):   5,
    (43, 45):   6
}

df['Hours_Studied'] = df['Hours_Studied'].apply(lambda x: remplazar(x, hs_studied))
df
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                 3           4                     0                    2
# 1                 2           0                     0                    1
# 2                 3           7                     1                    1
# 3                 4           5                     0                    1
# 4                 2           6                     1                    1
# ...             ...         ...                   ...                  ...
# 6602              3           1                     2                    1
# 6603              3           3                     2                    1
# 6604              2           5                     1                    0
# 6605              1           5                     2                    2
# 6606              2           1                     1                    0
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 0                              0            7                4
# 1                              0            8                1
# 2                              1            7                8
# 3                              1            8                9
# 4                              1            6                2
# ...                          ...          ...              ...
# 6602                           0            7                5
# 6603                           0            8                6
# 6604                           1            6                2
# 6605                           1            6                8
# 6606                           1            9                8
#
#       Motivation_Level  Internet_Access  Tutoring_Sessions  Family_Income  \
# 0                    0                1                  0              0
# 1                    0                1                  2              1
# 2                    1                1                  2              1
# 3                    1                1                  1              1
# 4                    1                1                  3              1
# ...                ...              ...                ...            ...
# 6602                 1                1                  1              2
# 6603                 1                1                  3              0
# 6604                 0                1                  3              0
# 6605                 2                1                  2              0
# 6606                 1                1                  0              1
#
#       Teacher_Quality  School_Type  Peer_Influence  Physical_Activity  \
# 0                 1.0            0               2                  3
# 1                 1.0            0               0                  4
# 2                 1.0            0               1                  4
# 3                 1.0            0               0                  4
# 4                 2.0            0               1                  4
# ...               ...          ...             ...                ...
# 6602              1.0            0               2                  2
# 6603              2.0            0               2                  2
# 6604              1.0            0               0                  2
# 6605              1.0            1               2                  3
# 6606              1.0            0               2                  4
#
#       Learning_Disabilities  Parental_Education_Level  Distance_from_Home  \
# 0                         0                       0.0                 0.0
# 1                         0                       1.0                 1.0
# 2                         0                       2.0                 0.0
# 3                         0                       0.0                 1.0
# 4                         0                       1.0                 0.0
# ...                     ...                       ...                 ...
# 6602                      0                       0.0                 0.0
# 6603                      0                       0.0                 0.0
# 6604                      0                       2.0                 0.0
# 6605                      0                       0.0                 2.0
# 6606                      0                       2.0                 0.0
#
#       Gender  Exam_Score
# 0          0           3
# 1          1           2
# 2          0           4
# 3          0           4
# 4          1           3
# ...      ...         ...
# 6602       1           3
# 6603       1           3
# 6604       1           3
# 6605       1           3
# 6606       0           2
#
# [6607 rows x 20 columns]

# %% [markdown]
# #### **Punto 5**: Transformaciones Preliminares:
#
# En los anteriores puntos, ya hice las conversiones necesarias.
